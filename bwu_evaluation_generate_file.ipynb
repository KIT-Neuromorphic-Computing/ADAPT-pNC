# %%
import pandas as pd

# %%
# %pwd
# Out:
# '/pfs/data5/home/kit/itec/qc0876/projects/LFV3/Learnable-Filter/24_Second_Order_Variation_Learnable_Filter'

# %%
# Read the CSV file
df = pd.read_csv('HyperParametersDataAugmentation.csv')

# Get the warp_factor value based on the dataset index
# warp_factor1 = df.loc[df['Dataset'] == 0, 'NOISE_LEVEL'].values[0]
[ds, nl1, wf1, sd1, su1, cs1] = df.loc[df['Dataset'] == 0].to_numpy()[0]
nl1 = float(nl1)
wf1 = float(wf1)
sd1 = float(sd1)
su1 = float(su1)
cs1 = int(cs1)

nl1, wf1, sd1, su1, cs1
# Out:
# (0.06497824538, 0.1666569224, 0.8474484242, 1.076289025, 50)

# %%
def generate_sh_file(dataset, project_name, e_train):
    job_name = f"{int(e_train*100)}_{dataset}_{dataset+1}_{dataset+2}_{dataset+3}_{dataset+4}"
    
    # Read the CSV file
    df = pd.read_csv('HyperParametersDataAugmentation.csv')

    [ds, nl0, wf0, sd0, su0, cs0] = df.loc[df['Dataset'] == dataset].to_numpy()[0]
    nl0, wf0, sd0, su0, cs0 = float(nl0), float(wf0), float(sd0), float(su0), int(cs0)
    
    [ds, nl1, wf1, sd1, su1, cs1] = df.loc[df['Dataset'] == (dataset+1)].to_numpy()[0]
    nl1, wf1, sd1, su1, cs1 = float(nl1), float(wf1), float(sd1), float(su1), int(cs1)
    
    [ds, nl2, wf2, sd2, su2, cs2] = df.loc[df['Dataset'] == (dataset+2)].to_numpy()[0]
    nl2, wf2, sd2, su2, cs2 = float(nl2), float(wf2), float(sd2), float(su2), int(cs2)
    
    [ds, nl3, wf3, sd3, su3, cs3] = df.loc[df['Dataset'] == (dataset+3)].to_numpy()[0]
    nl3, wf3, sd3, su3, cs3 = float(nl3), float(wf3), float(sd3), float(su3), int(cs3)
    
    [ds, nl4, wf4, sd4, su4, cs4] = df.loc[df['Dataset'] == (dataset+4)].to_numpy()[0]
    nl4, wf4, sd4, su4, cs4 = float(nl4), float(wf4), float(sd4), float(su4), int(cs4)
    
    content = f"""#!/bin/bash
    

#SBATCH --job-name={job_name}
#SBATCH --partition=single
#SBATCH --ntasks-per-node=40
#SBATCH --time=72:00:00
#SBATCH --error=%x.%j.err
#SBATCH --output=%x.o%j.%N


python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 0 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 1 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 2 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 3 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 4 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 5 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 6 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 7 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 8 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 9 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&

python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 0 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 1 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 2 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 3 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 4 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 5 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 6 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 7 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 8 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 9 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&

python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 0 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 1 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 2 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 3 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 4 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 5 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 6 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 7 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 8 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 9 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&

python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+3} --SEED 0 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl3} --WARP_FACTOR {wf3} --SFR_down {sd3} --SFR_up {su3} --CROP_SIZE {cs3} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+3} --SEED 1 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl3} --WARP_FACTOR {wf3} --SFR_down {sd3} --SFR_up {su3} --CROP_SIZE {cs3} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+3} --SEED 2 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl3} --WARP_FACTOR {wf3} --SFR_down {sd3} --SFR_up {su3} --CROP_SIZE {cs3} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+3} --SEED 3 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl3} --WARP_FACTOR {wf3} --SFR_down {sd3} --SFR_up {su3} --CROP_SIZE {cs3} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+3} --SEED 4 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl3} --WARP_FACTOR {wf3} --SFR_down {sd3} --SFR_up {su3} --CROP_SIZE {cs3} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+3} --SEED 5 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl3} --WARP_FACTOR {wf3} --SFR_down {sd3} --SFR_up {su3} --CROP_SIZE {cs3} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+3} --SEED 6 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl3} --WARP_FACTOR {wf3} --SFR_down {sd3} --SFR_up {su3} --CROP_SIZE {cs3} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+3} --SEED 7 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl3} --WARP_FACTOR {wf3} --SFR_down {sd3} --SFR_up {su3} --CROP_SIZE {cs3} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+3} --SEED 8 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl3} --WARP_FACTOR {wf3} --SFR_down {sd3} --SFR_up {su3} --CROP_SIZE {cs3} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+3} --SEED 9 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl3} --WARP_FACTOR {wf3} --SFR_down {sd3} --SFR_up {su3} --CROP_SIZE {cs3} --augment True --N_feature 1&

python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+4} --SEED 0 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl4} --WARP_FACTOR {wf4} --SFR_down {sd4} --SFR_up {su4} --CROP_SIZE {cs4} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+4} --SEED 1 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl4} --WARP_FACTOR {wf4} --SFR_down {sd4} --SFR_up {su4} --CROP_SIZE {cs4} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+4} --SEED 2 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl4} --WARP_FACTOR {wf4} --SFR_down {sd4} --SFR_up {su4} --CROP_SIZE {cs4} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+4} --SEED 3 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl4} --WARP_FACTOR {wf4} --SFR_down {sd4} --SFR_up {su4} --CROP_SIZE {cs4} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+4} --SEED 4 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl4} --WARP_FACTOR {wf4} --SFR_down {sd4} --SFR_up {su4} --CROP_SIZE {cs4} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+4} --SEED 5 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl4} --WARP_FACTOR {wf4} --SFR_down {sd4} --SFR_up {su4} --CROP_SIZE {cs4} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+4} --SEED 6 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl4} --WARP_FACTOR {wf4} --SFR_down {sd4} --SFR_up {su4} --CROP_SIZE {cs4} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+4} --SEED 7 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl4} --WARP_FACTOR {wf4} --SFR_down {sd4} --SFR_up {su4} --CROP_SIZE {cs4} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+4} --SEED 8 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl4} --WARP_FACTOR {wf4} --SFR_down {sd4} --SFR_up {su4} --CROP_SIZE {cs4} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+4} --SEED 9 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl4} --WARP_FACTOR {wf4} --SFR_down {sd4} --SFR_up {su4} --CROP_SIZE {cs4} --augment True --N_feature 1&

wait
"""
    with open(f"ratio_evaluation_{job_name}.sh", "w") as file:
        file.write(content)

# %%
def generate_sh_file(dataset, project_name, e_train):
    job_name = f"{dataset}_{dataset+1}_{dataset+2}_fr_{int(e_train*100)}"
    
    # Read the CSV file
    df = pd.read_csv('HyperParametersDataAugmentation.csv')

    [ds, nl0, wf0, sd0, su0, cs0] = df.loc[df['Dataset'] == dataset].to_numpy()[0]
    nl0, wf0, sd0, su0, cs0 = float(nl0), float(wf0), float(sd0), float(su0), int(cs0)
    
    [ds, nl1, wf1, sd1, su1, cs1] = df.loc[df['Dataset'] == (dataset+1)].to_numpy()[0]
    nl1, wf1, sd1, su1, cs1 = float(nl1), float(wf1), float(sd1), float(su1), int(cs1)
    
    [ds, nl2, wf2, sd2, su2, cs2] = df.loc[df['Dataset'] == (dataset+2)].to_numpy()[0]
    nl2, wf2, sd2, su2, cs2 = float(nl2), float(wf2), float(sd2), float(su2), int(cs2)
    # [ds, nl3, wf3, sd3, su3, cs3] = df.loc[df['Dataset'] == (dataset+3)].to_numpy()[0]
    # [ds, nl4, wf4, sd4, su4, cs4] = df.loc[df['Dataset'] == (dataset+4)].to_numpy()[0]
    
    content = f"""#!/bin/bash
    

#SBATCH --job-name={job_name}
#SBATCH --partition=single
#SBATCH --ntasks-per-node=35
#SBATCH --time=72:00:00
#SBATCH --error=%x.%j.err
#SBATCH --output=%x.o%j.%N


python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 0 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 1 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 2 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 3 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 4 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 5 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 6 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 7 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 8 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset} --SEED 9 --task temporal --loss celoss --opt adamw --LR 0.1 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl0} --WARP_FACTOR {wf0} --SFR_down {sd0} --SFR_up {su0} --CROP_SIZE {cs0} --augment True --N_feature 1&

python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 0 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 1 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 2 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 3 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 4 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 5 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 6 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 7 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 8 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+1} --SEED 9 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl1} --WARP_FACTOR {wf1} --SFR_down {sd1} --SFR_up {su1} --CROP_SIZE {cs1} --augment True --N_feature 1&

python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 0 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 1 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 2 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 3 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 4 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 5 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 6 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 7 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 8 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&
python3 exp_LearnableFilters.py --N_train 20 --e_train {e_train} --DATASET {dataset+2} --SEED 9 --task temporal --loss celoss --opt adamw --LR 0.01 --N_feature 1 --metric temporal_acc --projectname {project_name} --DEVICE cpu --PATIENCE 100 --NOISE_LEVEL {nl2} --WARP_FACTOR {wf2} --SFR_down {sd2} --SFR_up {su2} --CROP_SIZE {cs2} --augment True --N_feature 1&

wait
"""
    with open(f"ratio_evaluation_{job_name}.sh", "w") as file:
        file.write(content)

# %%
temporal_datasets = ['Dataset_cbf.tsds',
                         'Dataset_distalphalanxtw.tsds',
                         'Dataset_freezerregulartrain.tsds',
                         'Dataset_freezersmalltrain.tsds',
                         'Dataset_gunpointagespan.tsds',
                         'Dataset_gunpointmaleversusfemale.tsds',
                         'Dataset_gunpointoldversusyoung.tsds',
                         'Dataset_middlephalanxoutlineagegroup.tsds',
                         'Dataset_mixedshapesregulartrain.tsds',
                         'Dataset_powercons.tsds',
                         'Dataset_proximalphalanxoutlinecorrect.tsds',
                         'Dataset_selfregulationscp2.tsds',
                         'Dataset_slope.tsds',
                         'Dataset_smoothsubspace.tsds',
                         'Dataset_symbols.tsds']

# %%
import os

folder_path = 'dataset'
file_count = len(os.listdir(folder_path))
file_count = len(temporal_datasets)

# %%
dataset = range(0, file_count, 4)
for i in dataset:
    print(i)
# Out:
# 0
# 4
# 8
# 12

# %%
dataset = range(0, file_count, 3)
project_name = 'VariationAnalysis'
var_ratios = [0.0, 0.05, 0.1]

# %%
for ds in dataset:
    for var in var_ratios:
        pn=str(int(var*100))+'_'+project_name
        generate_sh_file(dataset=ds, project_name=pn, e_train=var)

# %%
file_count
# Out:
# 13

# %%
import glob
for var in var_ratios:
    files = glob.glob(f'ratio_evaluation_*fr_{int(var*100)}*')
    commands = []
    for file in files:
        command = f"sbatch {file}"
        print(command)
        commands.append(command)
    with open(f"run_evaluation_var_{int(var*100)}.sh", "w") as file_command:
        for command in commands:
            file_command.write(command + '\n')
        # Execute the command using os.system or subprocess.run
        # os.system(command)
        # subprocess.run(command, shell=True)
# Out:
# sbatch ratio_evaluation_0_1_2_fr_0.sh
# sbatch ratio_evaluation_3_4_5_fr_0.sh
# sbatch ratio_evaluation_9_10_11_fr_0.sh
# sbatch ratio_evaluation_12_13_14_fr_0.sh
# sbatch ratio_evaluation_6_7_8_fr_0.sh
# sbatch ratio_evaluation_3_4_5_fr_5.sh
# sbatch ratio_evaluation_9_10_11_fr_5.sh
# sbatch ratio_evaluation_6_7_8_fr_5.sh
# sbatch ratio_evaluation_0_1_2_fr_5.sh
# sbatch ratio_evaluation_12_13_14_fr_5.sh
# sbatch ratio_evaluation_3_4_5_fr_10.sh
# sbatch ratio_evaluation_12_13_14_fr_10.sh
# sbatch ratio_evaluation_0_1_2_fr_10.sh
# sbatch ratio_evaluation_9_10_11_fr_10.sh
# sbatch ratio_evaluation_6_7_8_fr_10.sh

# %%
import glob
for ds in dataset:
    if ds+1 >= file_count:
        break
    files = glob.glob(f'ratio_evaluation_{ds}_{ds+1}_{ds+2}_{ds+3}*')
    commands = []
    for file in files:
        command = f"sbatch {file}"
        print(command)
        commands.append(command)
    with open(f"run_evaluation_both_{ds}_{ds+1}_{ds+2}_{ds+3}.sh", "w") as file_command:
        for command in commands:
            file_command.write(command + '\n')
        # Execute the command using os.system or subprocess.run
        # os.system(command)
        # subprocess.run(command, shell=True)
# Out:
# sbatch ratio_evaluation_0_1_2_3_robust_0.1_sigmoid.sh
# sbatch ratio_evaluation_0_1_2_3_robust_0.05_cr.sh
# sbatch ratio_evaluation_0_1_2_3_normal_0.025_sigmoid.sh
# sbatch ratio_evaluation_0_1_2_3_normal_0.0_sigmoid.sh
# sbatch ratio_evaluation_0_1_2_3_normal_0.025_tanh.sh
# sbatch ratio_evaluation_0_1_2_3_robust_0.0_sigmoid.sh
# sbatch ratio_evaluation_0_1_2_3_normal_0.1_none.sh
# sbatch ratio_evaluation_0_1_2_3_normal_0.075_relu.sh
# sbatch ratio_evaluation_0_1_2_3_robust_0.0_tanh.sh
# sbatch ratio_evaluation_0_1_2_3_robust_0.05_relu.sh
# sbatch ratio_evaluation_0_1_2_3_normal_0.0_tanh.sh
# sbatch ratio_evaluation_0_1_2_3_robust_0.075_cr.sh
# sbatch ratio_evaluation_0_1_2_3_robust_0.05_none.sh
# sbatch ratio_evaluation_0_1_2_3_normal_0.05_cr.sh
# sbatch ratio_evaluation_0_1_2_3_normal_0.05_sigmoid.sh
# sbatch ratio_evaluation_0_1_2_3_robust_0.075_tanh.sh
# sbatch ratio_evaluation_0_1_2_3_normal_0.05_none.sh
# sbatch ratio_evaluation_0_1_2_3_normal_0.025_cr.sh
# ...
